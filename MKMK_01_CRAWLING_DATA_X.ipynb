# %%
# !pip install pandas
# !curl -sL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# ...
#
# ...
# ▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
# ...
#
#                            SCRIPT DEPRECATION WARNING
#
#
#   This script, located at https://deb.nodesource.com/setup_X, used to
#   install Node.js is deprecated now and will eventually be made inactive.
#
#   Please visit the NodeSource distributions Github and follow the
#   instructions to migrate your repo.
#   https://github.com/nodesource/distributions
#
#   The NodeSource Node.js Linux distributions GitHub repository contains
#   information about which versions of Node.js and which Linux distributions
#   are supported and how to install it.
#   https://github.com/nodesource/distributions
#
#
#                           SCRIPT DEPRECATION WARNING
#
# ...
# ▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓
# ...
#
# TO AVOID THIS WAIT MIGRATE THE SCRIPT
# Continuing in 60 seconds (press Ctrl-C to abort) ...
#
#
# ## Installing the NodeSource Node.js 18.x repo...
#
#
# ...

# %% [markdown]
# # ***CRAWLING DATA TWITTER/X HARUS MENGGUNAKAN auth_token***
# https://twitter.com/

# %%
dataset = 'MKMK.csv'
search_keyword = 'MKMK until:2023-11-07 since:2023-06-01'
limit = 2000

# !npx --yes tweet-harvest@2.2.8 -o "{dataset}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %% [markdown]
# # ***READ DATASET CRAWLING TWITTER/X***

# %%
import pandas as pd

data = pd.read_csv("/content/tweets-data/MKMK.csv", sep=";")
data.head(5)
# Out:
#                        created_at               id_str  \
# 0  Mon Nov 06 23:58:01 +0000 2023  1721678354594893837
# 1  Mon Nov 06 23:56:58 +0000 2023  1721678088189473023
# 2  Mon Nov 06 23:56:07 +0000 2023  1721677877392064649
# 3  Mon Nov 06 23:55:02 +0000 2023  1721677603185275391
# 4  Mon Nov 06 23:53:47 +0000 2023  1721677287052165618
#
#                                            full_text  quote_count  \
# 0               @mkmk_nikkori めんた～～～～♥️♥️うれしいありがとうすき            0
# 1                @jumpingokami 坂ちんかわいい？ちょっと見てみようかなぁ🤔            0
# 2  @tvOneNews semoga MKMK tidak ngeprank kita semua.            0
# 3                           いや㊙️情報じゃなくてそもそも可愛いだろ舐めんな            0
# 4                          ジャングルポケット㊙️情報  めちゃくちゃかわいい            0
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0            0              0               0   ja  1654045315358679040
# 1            1              0               0   ja           2315068182
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           553 non-null    object
#  1   id_str               553 non-null    int64
#  2   full_text            553 non-null    object
#  3   quote_count          553 non-null    int64
#  4   reply_count          553 non-null    int64
#  5   retweet_count        553 non-null    int64
#  6   favorite_count       553 non-null    int64
#  7   lang                 553 non-null    object
#  8   user_id_str          553 non-null    int64
#  9   conversation_id_str  553 non-null    int64
#  10  username             553 non-null    object
#  11  tweet_url            553 non-null    object
# dtypes: int64(7), object(5)
# memory usage: 52.0+ KB
